# %% [markdown]
# # Comparativa CNN: API **Secuencial** vs **Funcional** (Google Colab)
# **Objetivo:** entrenar y comparar dos CNN (misma arquitectura y datos) implementadas con la API *Sequential* y la API *Functional* de Keras/TensorFlow sobre MNIST.
# - Entrenamiento: primero **Secuencial** (todas las épocas de un jalón) y luego **Funcional**.
# - Comparación: tabla + gráficas (loss / accuracy) y predicciones sobre las mismas imágenes.
# - Comentarios: cada bloque y líneas clave incluyen referencias (documentación oficial y tutoriales externos) como comentarios dentro del código.

# %%
# =======================
# 0) Configuración y parámetros
# =======================
# Importes principales (TensorFlow/Keras, numpy, matplotlib, pandas, time)
# Fuente (docs): Keras/TensorFlow guide. https://www.tensorflow.org/guide/keras
import tensorflow as tf                              # API principal de TensorFlow (incluye Keras)
import numpy as np                                   # manejo de arrays numéricos
import matplotlib.pyplot as plt                      # graficado de curvas y ejemplos
import pandas as pd                                  # tablas para comparar resultados
import time                                          # medir tiempos de entrenamiento

# Parámetros configurables
BATCH_SIZE = 64
EPOCHS = 50                 # Cambia este valor a gusto. Recomendación inicial: 20 (buen tradeoff para MNIST)
VALIDATION_SPLIT = 0.10
RANDOM_SEED = 42

# Habilitar modo inline para Jupyter/Colab (muestras de graficas)
# %matplotlib inline

# Detectar GPUs (si Colab tiene GPU activada). Recomendación: seleccionar Hardware accelerator -> GPU.
# Fuente (Colab GPU guide): https://colab.research.google.com/notebooks/gpu.ipynb
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f'GPUs detectadas: {len(gpus)}. Se intentará usar GPU para entrenamiento.')
    try:
        for gpu in gpus:
            # Evita que TF consuma toda la memoria GPU inmediatamente
            tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print('No se pudo establecer memory growth en GPU:', e)
else:
    print('No se detectó GPU: el entrenamiento se realizará en CPU.')
# Out:
# GPUs detectadas: 1. Se intentará usar GPU para entrenamiento.

# %%
# =======================
# 1) Cargar y preprocesar MNIST
# =======================
# Cargar MNIST (toy dataset): 60k train (28x28), 10k test.
# Fuente: tf.keras.datasets.mnist.load_data() docs. https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Revisar shapes (opcional), aquí comentado para no spamear en ejecución
# print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)  # (60000,28,28) (60000,) (10000,28,28) (10000,)

# Normalizar (0-1) y agregar canal final para Conv2D (shape -> (N,28,28,1))
X_train = X_train.astype('float32') / 255.0
X_test  = X_test.astype('float32') / 255.0
X_train = X_train.reshape((-1, 28, 28, 1))
X_test  = X_test.reshape((-1, 28, 28, 1))

# One-hot encoding para la salida (10 clases)
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train, num_classes=10)
y_test_cat  = to_categorical(y_test,  num_classes=10)

# Fijar semilla para reproducibilidad (en la medida de lo posible)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
# =======================
# 2) Construir y entrenar modelo SECUENCIAL (todo en un jalón)
# =======================
# Usamos tf.keras.Sequential: apropiado para stacks lineales de capas.
# Documentacion Sequential: https://www.tensorflow.org/api_docs/python/tf/keras/Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

def build_sequential_model():
    # Arquitectura: (misma que en el archivo original que subiste)
    # Input -> Conv2D(64,3x3) -> MaxPool -> Conv2D(128,3x3) -> MaxPool -> Flatten -> Dense(128) -> Dense(10 softmax)
    model = Sequential([
        Input(shape=(28,28,1), name='seq_input'),                     # Capa de entrada explícita
        Conv2D(64, kernel_size=(3,3), activation='relu', name='seq_conv2d_1'),  # Conv1 (64 filtros)
        MaxPooling2D(pool_size=(2,2), name='seq_pool1'),              # Reducción espacial
        Conv2D(128, kernel_size=(3,3), activation='relu', name='seq_conv2d_2'), # Conv2 (128 filtros)
        MaxPooling2D(pool_size=(2,2), name='seq_pool2'),
        Flatten(name='seq_flatten'),
        Dense(128, activation='relu', name='seq_dense128'),
        Dense(10, activation='softmax', name='seq_output')
    ])
    return model

# Construcción y compilación
seq_model = build_sequential_model()
# Compilación: Adam optimizer, categorical_crossentropy loss y metric accuracy
# Fuente model.compile: https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile
seq_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Resumen (imprime la arquitectura)
print('--- Resumen Modelo SECUENCIAL ---')
seq_model.summary()

# Entrenamiento: un solo llamado a fit() con EPOCHS definidas arriba.
# Devuelve History con métricas por época.
start_time = time.time()
history_seq = seq_model.fit(
    X_train, y_train_cat,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VALIDATION_SPLIT,
    verbose=2
)
time_seq = time.time() - start_time

# Evaluación final sobre conjunto de test
loss_seq, acc_seq = seq_model.evaluate(X_test, y_test_cat, verbose=0)
print(f'SECUENCIAL -> loss: {loss_seq:.4f}, accuracy: {acc_seq:.4f}, tiempo(s): {time_seq:.1f}')

# Guardar modelo entrenado (archivo .keras)
seq_model.save('cnn_secuencial.keras')  # se guarda en el workspace de Colab
# Out:
# --- Resumen Modelo SECUENCIAL ---
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ seq_conv2d_1 (Conv2D)           │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_pool1 (MaxPooling2D)        │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_conv2d_2 (Conv2D)           │ (None, 11, 11, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_pool2 (MaxPooling2D)        │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_flatten (Flatten)           │ (None, 3200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_dense128 (Dense)            │ (None, 128)            │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ seq_output (Dense)              │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 485,514 (1.85 MB)
#  Trainable params: 485,514 (1.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 844/844 - 8s - 10ms/step - accuracy: 0.9571 - loss: 0.1398 - val_accuracy: 0.9835 - val_loss: 0.0550
# Epoch 2/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9869 - loss: 0.0423 - val_accuracy: 0.9877 - val_loss: 0.0437
# Epoch 3/50
# 844/844 - 4s - 5ms/step - accuracy: 0.9917 - loss: 0.0269 - val_accuracy: 0.9865 - val_loss: 0.0477
# Epoch 4/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9941 - loss: 0.0186 - val_accuracy: 0.9893 - val_loss: 0.0434
# Epoch 5/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9957 - loss: 0.0137 - val_accuracy: 0.9898 - val_loss: 0.0442
# Epoch 6/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9962 - loss: 0.0114 - val_accuracy: 0.9888 - val_loss: 0.0453
# Epoch 7/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9968 - loss: 0.0098 - val_accuracy: 0.9910 - val_loss: 0.0435
# Epoch 8/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9907 - val_loss: 0.0426
# Epoch 9/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9910 - val_loss: 0.0469
# Epoch 10/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9978 - loss: 0.0067 - val_accuracy: 0.9888 - val_loss: 0.0579
# Epoch 11/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9978 - loss: 0.0066 - val_accuracy: 0.9907 - val_loss: 0.0457
# Epoch 12/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9920 - val_loss: 0.0487
# Epoch 13/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9927 - val_loss: 0.0497
# Epoch 14/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9986 - loss: 0.0041 - val_accuracy: 0.9917 - val_loss: 0.0519
# Epoch 15/50
# 844/844 - 5s - 6ms/step - accuracy: 0.9986 - loss: 0.0041 - val_accuracy: 0.9897 - val_loss: 0.0536
# Epoch 16/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9917 - val_loss: 0.0573
# Epoch 17/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9918 - val_loss: 0.0545
# Epoch 18/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9933 - val_loss: 0.0434
# Epoch 19/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.9920 - val_loss: 0.0489
# Epoch 20/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9993 - loss: 0.0020 - val_accuracy: 0.9908 - val_loss: 0.0655
# Epoch 21/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9988 - loss: 0.0034 - val_accuracy: 0.9915 - val_loss: 0.0600
# Epoch 22/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9933 - val_loss: 0.0542
# Epoch 23/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9923 - val_loss: 0.0556
# Epoch 24/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9923 - val_loss: 0.0629
# Epoch 25/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9942 - val_loss: 0.0597
# Epoch 26/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9923 - val_loss: 0.0646
# Epoch 27/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9912 - val_loss: 0.0691
# Epoch 28/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9925 - val_loss: 0.0581
# Epoch 29/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 0.9928 - val_loss: 0.0536
# Epoch 30/50
# 844/844 - 4s - 5ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9943 - val_loss: 0.0595
# Epoch 31/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9925 - val_loss: 0.0643
# Epoch 32/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9910 - val_loss: 0.0651
# Epoch 33/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9927 - val_loss: 0.0611
# Epoch 34/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9928 - val_loss: 0.0530
# Epoch 35/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.9938 - val_loss: 0.0523
# Epoch 36/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9933 - val_loss: 0.0543
# Epoch 37/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9999 - loss: 1.7108e-04 - val_accuracy: 0.9930 - val_loss: 0.0580
# Epoch 38/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9907 - val_loss: 0.0990
# Epoch 39/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9991 - loss: 0.0039 - val_accuracy: 0.9925 - val_loss: 0.0679
# Epoch 40/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9930 - val_loss: 0.0802
# Epoch 41/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9908 - val_loss: 0.0859
# Epoch 42/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9912 - val_loss: 0.0801
# Epoch 43/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9925 - val_loss: 0.0648
# Epoch 44/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0018 - val_accuracy: 0.9915 - val_loss: 0.0747
# Epoch 45/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9915 - val_loss: 0.0923
# Epoch 46/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9933 - val_loss: 0.0825
# Epoch 47/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9907 - val_loss: 0.1048
# Epoch 48/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9927 - val_loss: 0.0751
# Epoch 49/50
# 844/844 - 3s - 4ms/step - accuracy: 1.0000 - loss: 2.6448e-05 - val_accuracy: 0.9928 - val_loss: 0.0735
# Epoch 50/50
# 844/844 - 3s - 4ms/step - accuracy: 1.0000 - loss: 1.6678e-06 - val_accuracy: 0.9932 - val_loss: 0.0730
# SECUENCIAL -> loss: 0.0520, accuracy: 0.9940, tiempo(s): 182.8

# %%
# =======================
# 3) Construir y entrenar modelo FUNCIONAL (todo en un jalón)
# =======================
# Functional API: permite topologías más complejas (DAG), múltiples entradas/salidas, etc.
# Fuente: Functional API guide. https://www.tensorflow.org/guide/keras/functional_api
from tensorflow.keras import Input as KInput
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D as KConv2D, MaxPooling2D as KMaxPool, Flatten as KFlatten, Dense as KDense

def build_functional_model():
    inputs = KInput(shape=(28,28,1), name='func_input')
    x = KConv2D(64, (3,3), activation='relu', name='func_conv2d_1')(inputs)
    x = KMaxPool((2,2), name='func_pool1')(x)
    x = KConv2D(128, (3,3), activation='relu', name='func_conv2d_2')(x)
    x = KMaxPool((2,2), name='func_pool2')(x)
    x = KFlatten(name='func_flatten')(x)
    x = KDense(128, activation='relu', name='func_dense128')(x)
    outputs = KDense(10, activation='softmax', name='func_output')(x)
    model = Model(inputs=inputs, outputs=outputs, name='cnn_funcional')
    return model

# Construcción y compilación
func_model = build_functional_model()
func_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print('--- Resumen Modelo FUNCIONAL ---')
func_model.summary()

# Entrenamiento
start_time = time.time()
history_func = func_model.fit(
    X_train, y_train_cat,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VALIDATION_SPLIT,
    verbose=2
)
time_func = time.time() - start_time

loss_func, acc_func = func_model.evaluate(X_test, y_test_cat, verbose=0)
print(f'FUNCIONAL -> loss: {loss_func:.4f}, accuracy: {acc_func:.4f}, tiempo(s): {time_func:.1f}')

# Guardar modelo
func_model.save('cnn_funcional.keras')
# Out:
# --- Resumen Modelo FUNCIONAL ---
# Model: "cnn_funcional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ func_input (InputLayer)         │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_conv2d_1 (Conv2D)          │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_pool1 (MaxPooling2D)       │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_conv2d_2 (Conv2D)          │ (None, 11, 11, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_pool2 (MaxPooling2D)       │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_flatten (Flatten)          │ (None, 3200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_dense128 (Dense)           │ (None, 128)            │       409,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ func_output (Dense)             │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 485,514 (1.85 MB)
#  Trainable params: 485,514 (1.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 844/844 - 8s - 9ms/step - accuracy: 0.9558 - loss: 0.1432 - val_accuracy: 0.9835 - val_loss: 0.0547
# Epoch 2/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9865 - loss: 0.0427 - val_accuracy: 0.9863 - val_loss: 0.0475
# Epoch 3/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9915 - loss: 0.0276 - val_accuracy: 0.9855 - val_loss: 0.0493
# Epoch 4/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9934 - loss: 0.0198 - val_accuracy: 0.9893 - val_loss: 0.0444
# Epoch 5/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.9908 - val_loss: 0.0390
# Epoch 6/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9960 - loss: 0.0125 - val_accuracy: 0.9887 - val_loss: 0.0418
# Epoch 7/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9969 - loss: 0.0093 - val_accuracy: 0.9912 - val_loss: 0.0420
# Epoch 8/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9975 - loss: 0.0076 - val_accuracy: 0.9912 - val_loss: 0.0397
# Epoch 9/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9908 - val_loss: 0.0428
# Epoch 10/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9935 - val_loss: 0.0365
# Epoch 11/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9905 - val_loss: 0.0514
# Epoch 12/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9982 - loss: 0.0049 - val_accuracy: 0.9907 - val_loss: 0.0529
# Epoch 13/50
# 844/844 - 4s - 5ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9918 - val_loss: 0.0450
# Epoch 14/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9932 - val_loss: 0.0424
# Epoch 15/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9903 - val_loss: 0.0670
# Epoch 16/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9930 - val_loss: 0.0470
# Epoch 17/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9915 - val_loss: 0.0677
# Epoch 18/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9923 - val_loss: 0.0514
# Epoch 19/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9932 - val_loss: 0.0463
# Epoch 20/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9922 - val_loss: 0.0566
# Epoch 21/50
# 844/844 - 5s - 6ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9923 - val_loss: 0.0631
# Epoch 22/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.9922 - val_loss: 0.0660
# Epoch 23/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9887 - val_loss: 0.0761
# Epoch 24/50
# 844/844 - 5s - 6ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9902 - val_loss: 0.0663
# Epoch 25/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9912 - val_loss: 0.0756
# Epoch 26/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.9922 - val_loss: 0.0791
# Epoch 27/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9902 - val_loss: 0.0658
# Epoch 28/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9937 - val_loss: 0.0459
# Epoch 29/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9927 - val_loss: 0.0593
# Epoch 30/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9903 - val_loss: 0.0864
# Epoch 31/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9922 - val_loss: 0.0674
# Epoch 32/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9997 - loss: 8.8936e-04 - val_accuracy: 0.9937 - val_loss: 0.0671
# Epoch 33/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9999 - loss: 5.8050e-04 - val_accuracy: 0.9937 - val_loss: 0.0762
# Epoch 34/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9910 - val_loss: 0.0709
# Epoch 35/50
# 844/844 - 5s - 6ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9925 - val_loss: 0.0701
# Epoch 36/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9928 - val_loss: 0.0629
# Epoch 37/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9994 - loss: 0.0018 - val_accuracy: 0.9940 - val_loss: 0.0605
# Epoch 38/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9997 - loss: 8.0305e-04 - val_accuracy: 0.9910 - val_loss: 0.0776
# Epoch 39/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9927 - val_loss: 0.0636
# Epoch 40/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9935 - val_loss: 0.0622
# Epoch 41/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9917 - val_loss: 0.0751
# Epoch 42/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.9927 - val_loss: 0.0745
# Epoch 43/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9932 - val_loss: 0.0663
# Epoch 44/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9998 - loss: 5.9211e-04 - val_accuracy: 0.9942 - val_loss: 0.0714
# Epoch 45/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9933 - val_loss: 0.0660
# Epoch 46/50
# 844/844 - 4s - 5ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9932 - val_loss: 0.0579
# Epoch 47/50
# 844/844 - 3s - 4ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9923 - val_loss: 0.0697
# Epoch 48/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9913 - val_loss: 0.0870
# Epoch 49/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9927 - val_loss: 0.0690
# Epoch 50/50
# 844/844 - 4s - 4ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9933 - val_loss: 0.0643
# FUNCIONAL -> loss: 0.0583, accuracy: 0.9928, tiempo(s): 185.7

# %%
# =======================
# 4) Comparación y visualización de resultados
# =======================
# Tabla resumen con métricas finales y tiempos de entrenamiento

results = pd.DataFrame({
    'Modelo': ['Secuencial', 'Funcional'],
    'Loss_test': [loss_seq, loss_func],
    'Accuracy_test': [acc_seq, acc_func],
    'Tiempo_s': [round(time_seq,1), round(time_func,1)]
})
print('--- Resumen final ---')
display(results)

# Graficar curvas de loss y accuracy para ambos modelos (train/val)
epochs_range = range(1, EPOCHS+1)

plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(epochs_range, history_seq.history['loss'], marker='o', label='Seq train loss')
plt.plot(epochs_range, history_seq.history['val_loss'], marker='o', label='Seq val loss')
plt.plot(epochs_range, history_func.history['loss'], marker='x', label='Func train loss')
plt.plot(epochs_range, history_func.history['val_loss'], marker='x', label='Func val loss')
plt.title('Loss: Secuencial vs Funcional')
plt.xlabel('Época'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)

plt.subplot(1,2,2)
plt.plot(epochs_range, history_seq.history['accuracy'], marker='o', label='Seq train acc')
plt.plot(epochs_range, history_seq.history['val_accuracy'], marker='o', label='Seq val acc')
plt.plot(epochs_range, history_func.history['accuracy'], marker='x', label='Func train acc')
plt.plot(epochs_range, history_func.history['val_accuracy'], marker='x', label='Func val acc')
plt.title('Accuracy: Secuencial vs Funcional')
plt.xlabel('Época'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)

plt.tight_layout()
plt.show()

# Mostrar predicciones sobre el mismo conjunto de imágenes para comparar
n_examples = 6
indices = np.random.choice(len(X_test), n_examples, replace=False)
images = X_test[indices]

preds_seq = seq_model.predict(images)
preds_func = func_model.predict(images)

plt.figure(figsize=(12,4))
for i, idx in enumerate(indices):
    ax = plt.subplot(2, n_examples, i+1)
    plt.imshow(images[i].reshape(28,28), cmap='gray')
    plt.title(f'True: {np.argmax(y_test_cat[idx])}')
    plt.axis('off')
    ax2 = plt.subplot(2, n_examples, i+1+n_examples)
    plt.axis('off')
    txt = f"Seq: {np.argmax(preds_seq[i])} ({preds_seq[i].max():.2%})\nFunc: {np.argmax(preds_func[i])} ({preds_func[i].max():.2%})"
    ax2.text(0.1, 0.5, txt, fontsize=12, va='center', ha='left')
plt.suptitle('Comparación de predicciones - Secuencial vs Funcional', fontsize=14)
plt.show()

# Guardar historiales localmente (json) para análisis posterior
import json
with open('history_seq.json','w') as f:
    json.dump(history_seq.history, f)
with open('history_func.json','w') as f:
    json.dump(history_func.history, f)

print('Archivos guardados: cnn_secuencial.keras, cnn_funcional.keras, history_seq.json, history_func.json')
# Out:
# --- Resumen final ---
#        Modelo  Loss_test  Accuracy_test  Tiempo_s
# 0  Secuencial   0.051952         0.9940     182.8
# 1   Funcional   0.058350         0.9928     185.7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Archivos guardados: cnn_secuencial.keras, cnn_funcional.keras, history_seq.json, history_func.json

# %% [markdown]
# # Referencias utilizadas (documentación oficial y tutoriales)
# Se listan las fuentes principales que incluí como comentarios en el código (docs oficiales y tutoriales externos):
#
# 1. TensorFlow / Keras — Sequential API. https://www.tensorflow.org/api_docs/python/tf/keras/Sequential
# 2. TensorFlow — Functional API guide. https://www.tensorflow.org/guide/keras/functional_api
# 3. tf.keras.datasets.mnist.load_data documentation. https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data
# 4. Conv2D layer docs. https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D
# 5. Using GPU in Colab (Colab GPU notebook). https://colab.research.google.com/notebooks/gpu.ipynb
# 6. Comparison article: Sequential vs Functional (Analytics Vidhya / Medium). https://medium.com/analytics-vidhya/keras-model-sequential-api-vs-functional-api-fc1439a6fb10
# 7. Keras datasets overview. https://keras.io/api/datasets/
# 8. Use a GPU (TensorFlow guide). https://www.tensorflow.org/guide/gpu
# 9. Conv2D detailed (Keras): https://keras.io/api/layers/convolution_layers/convolution2d/
# 10. Keras guide overview. https://www.tensorflow.org/guide/keras
