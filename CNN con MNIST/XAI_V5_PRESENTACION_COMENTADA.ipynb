# %% [markdown]
# # 🧠 Análisis XAI con Grad-CAM usando CNN y Xception
# Este notebook presenta un enfoque de *Explainable Artificial Intelligence (XAI)* aplicado a modelos de redes neuronales convolucionales (CNN), utilizando la técnica Grad-CAM para la interpretación visual de predicciones sobre el conjunto de datos **MNIST**. El objetivo es analizar las regiones más relevantes que influyen en las decisiones del modelo.
#
# **Autor:** [Tu nombre aquí]
# **Institución:** Instituto Tecnológico de Apizaco
# **Proyecto:** E2-Ente — Interpretabilidad de modelos CNN
#
# ---

# %% [markdown]
# ## 🎯 Objetivo
# Implementar y analizar visualmente un modelo CNN basado en la arquitectura **Xception**, adaptado al conjunto de datos **MNIST**, mediante la aplicación de **Grad-CAM** para identificar las áreas más influyentes en la clasificación de imágenes de dígitos manuscritos.
#
# ---

# %% [markdown]
# ## 🧩 Descripción general
# El notebook realiza los siguientes pasos:
# 1. Carga y preprocesamiento del conjunto de datos MNIST.
# 2. Adaptación del modelo **Xception** para imágenes de un solo canal (escala de grises).
# 3. Entrenamiento y evaluación del modelo.
# 4. Implementación del método **Grad-CAM** para generar mapas de activación.
# 5. Visualización e interpretación de resultados.
#
# ---

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# =========================
# 0) IMPORTS Y CONFIGURACIÓN
# =========================
# Importamos librerías básicas y Keras/TensorFlow
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# 
# TensorFlow / Keras
# import tensorflow as tf
# Cargar y preprocesar los datos (ej. MNIST).
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
# from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras import layers
# 
# Configuración estética para gráficas
# sns.set(font_scale=1.2)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.style.use('seaborn-v0_8-darkgrid')
# 
# Fijamos una semilla para reproducibilidad (opcional)
# np.random.seed(42)
# tf.random.set_seed(42)
# 
# print('Librerías cargadas correctamente. TensorFlow version:', tf.__version__)
#
# Out:
# Librerías cargadas correctamente. TensorFlow version: 2.19.0

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# ============================================
# Cargar y preprocesar los datos (ej. MNIST).
# 1) CARGA Y PREPROCESAMIENTO DEL DATASET MNIST
# ============================================
# Cargar y preprocesar los datos (ej. MNIST).
# Cargamos MNIST (imágenes 28x28 de dígitos 0-9)
# Cargar y preprocesar los datos (ej. MNIST).
# (X_train, y_train), (X_test, y_test) = mnist.load_data()
# 
# Normalizamos los pixeles a rango [0,1] y convertimos a float32
# X_train = X_train.astype('float32') / 255.0
# X_test  = X_test.astype('float32')  / 255.0
# 
# Añadimos el canal de profundidad (1) → shape (N,28,28,1)
# X_train = np.expand_dims(X_train, -1)
# X_test  = np.expand_dims(X_test, -1)
# 
# Convertimos etiquetas a one-hot para clasificación con las CNNs
# y_train_cat = to_categorical(y_train, 10)
# y_test_cat  = to_categorical(y_test, 10)
# 
# print('Shapes:')
# print('  X_train:', X_train.shape)
# print('  X_test :', X_test.shape)
# print('  y_train (categorical):', y_train_cat.shape)
# print('  y_test (categorical):', y_test_cat.shape)
#
# Out:
# Shapes:
#   X_train: (60000, 28, 28, 1)
#   X_test : (10000, 28, 28, 1)
#   y_train (categorical): (60000, 10)
#   y_test (categorical): (10000, 10)

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# ============================================
# 2) DEFINICIÓN DE MODELO CNN
# ============================================
# 
# MODELO CNN Profunda (2 conv + pool, luego otras 2 conv + pool)
# inputs2 = Input(shape=(28,28,1), name='input_profundo')
# Bloque 1: 2 convoluciones seguidas y pooling
# x2 = Conv2D(32, (3,3), activation='relu', padding='same', name='conv2d_1')(inputs2)
# x2 = Conv2D(64, (3,3), activation='relu', padding='same', name='conv2d_2')(x2)
# x2 = MaxPooling2D((2,2), name='maxpool_1')(x2)
# Bloque 2: otras 2 convoluciones y pooling
# x2 = Conv2D(128, (3,3), activation='relu', padding='same', name='conv2d_3')(x2)
# x2 = Conv2D(256, (3,3), activation='relu', padding='same', name='conv2d_4')(x2)
# x2 = MaxPooling2D((2,2), name='maxpool_2')(x2)
# Final
# x2 = Flatten(name='flatten')(x2)
# x2 = Dense(256, activation='relu', name='dense_256')(x2)
# outputs2 = Dense(10, activation='softmax', name='output')(x2)
# 
# Construcción o carga del modelo: arquitectura y pesos.
# cnn_profundo = Model(inputs2, outputs2, name='CNN_Profundo')
# cnn_profundo.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
# 
# print('\nModelo creado CNN Profundo')
#
# Out:
# Modelo creado CNN Profundo

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# Mostrar resúmenes (arquitectura y parámetros)
# print('\n--- Resumen: CNN Profundo ---')
# cnn_profundo.summary()
# Out:
# --- Resumen: CNN Profundo ---
# Model: "CNN_Profundo"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_profundo (InputLayer)     │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_1 (MaxPooling2D)        │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# ============================================
# 3) ENTRENAMIENTO
# ============================================
# epochs = 50        # Ajusta según recurso (Colab GPU: sube si quieres)
# batch_size = 128
# 
# Entrenamos la CNN profunda (mismas condiciones)
# history_profundo = cnn_profundo.fit(
#     X_train, y_train_cat,
#     validation_split=0.1,
#     epochs=epochs,
#     batch_size=batch_size,
#     verbose=1
# )
#
# Out:
# Epoch 1/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - accuracy: 0.8984 - loss: 0.3223 - val_accuracy: 0.9865 - val_loss: 0.0446
# Epoch 2/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.9880 - val_loss: 0.0430
# Epoch 3/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9925 - loss: 0.0237 - val_accuracy: 0.9900 - val_loss: 0.0374
# Epoch 4/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9943 - loss: 0.0173 - val_accuracy: 0.9893 - val_loss: 0.0369
# Epoch 5/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9956 - loss: 0.0140 - val_accuracy: 0.9903 - val_loss: 0.0380
# Epoch 6/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9878 - val_loss: 0.0642
# Epoch 7/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9957 - loss: 0.0112 - val_accuracy: 0.9887 - val_loss: 0.0523
# Epoch 8/50
# ...

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# ============================================
# 4) COMPARACIÓN VISUAL: Accuracy y Loss
# ============================================
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.figure(figsize=(14,5))
# 
# Accuracy
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.subplot(1,2,1)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.plot(history_profundo.history['accuracy'], marker='o', label='Profundo - Train')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.plot(history_profundo.history['val_accuracy'], marker='x', label='Profundo - Val')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.title('Accuracy')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.xlabel('Épocas')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.ylabel('Accuracy')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.legend()
# 
# Loss
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.subplot(1,2,2)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.plot(history_profundo.history['loss'], marker='o', label='Profundo - Train')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.plot(history_profundo.history['val_loss'], marker='x', label='Profundo - Val')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.title('Loss')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.xlabel('Épocas')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.ylabel('Loss')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.legend()
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.tight_layout()
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.show()
#

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# import matplotlib.pyplot as plt
# import numpy as np
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Conv2D
# Cargar y preprocesar los datos (ej. MNIST).
# from tensorflow.keras.datasets import mnist
# import numpy as np
# 
# Cargar y preprocesar los datos (ej. MNIST).
# Cargar datos MNIST
# Cargar y preprocesar los datos (ej. MNIST).
# (_, _), (x_test, _) = mnist.load_data()
# 
# Seleccionar una imagen de prueba y darle forma correcta
# base_img = x_test[0].astype('float32') / 255.0
# base_img = np.expand_dims(base_img, axis=-1)  # Añadir canal (28,28,1)
# 
# 
# Definición de función: plot_conv_filters — explica qué hace y sus parámetros.
# def plot_conv_filters(model, img, layer_name, model_name="CNN"):
# 
#     if img.ndim == 3:
#         img = img[np.newaxis, ...]
# 
#     layer = model.get_layer(layer_name)
#     weights, biases = layer.get_weights()
# Construcción o carga del modelo: arquitectura y pesos.
#     act_model = Model(inputs=model.input, outputs=layer.output)
# Predicción: obtener probabilidades o etiquetas desde el modelo entrenado.
#     activations = act_model.predict(img)[0]
# 
#     n_filters = activations.shape[-1]
#     n_cols = 8
#     n_rows = int(np.ceil(n_filters / n_cols))
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.figure(figsize=(n_cols*2, n_rows*2))
#     for i in range(n_filters):
#         kernel = weights[:, :, 0, i]
#         mean_w = np.mean(kernel)
#         std_w = np.std(kernel)
#         min_w = np.min(kernel)
#         max_w = np.max(kernel)
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         plt.subplot(n_rows, n_cols, i+1)
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         plt.imshow(activations[:, :, i], cmap='gray')
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         plt.axis('off')
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         plt.title(f"F{i} | μ={mean_w:.2f} σ={std_w:.2f}\n[{min_w:.2f}, {max_w:.2f}]", fontsize=7)
# 
    # --- Ajuste del espaciado del título ---
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.suptitle(f"Activaciones y pesos (numéricos)\n{model_name} - {layer_name}", fontsize=13, y=1.02)
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.tight_layout(rect=[0, 0, 1, 0.96])
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.show()
# 
# 
# Definición de función: plot_all_conv_layers — explica qué hace y sus parámetros.
# def plot_all_conv_layers(model, img, model_name="CNN"):
#     """
#     Muestra las activaciones y pesos numéricos de todas las capas Conv2D de un modelo.
#     """
#     conv_layers = [layer.name for layer in model.layers if isinstance(layer, Conv2D)]
# 
#     if not conv_layers:
#         print(f"{model_name}: No se encontraron capas convolucionales.")
#         return
# 
#     print(f"\n=== {model_name}: {len(conv_layers)} capas convolucionales detectadas ===\n")
#     for lname in conv_layers:
#         print(f"Procesando capa: {lname}")
#         plot_conv_filters(model, img, lname, model_name)
# 
# 
# --- Uso ---
# plot_all_conv_layers(cnn_profundo, base_img, "CNN Profundo")
#
# Out:
# === CNN Profundo: 4 capas convolucionales detectadas ===
#
# Procesando capa: conv2d_1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Procesando capa: conv2d_2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Procesando capa: conv2d_3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Procesando capa: conv2d_4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# Definición de función: plot_activation_summary — explica qué hace y sus parámetros.
# def plot_activation_summary(model, img, layer_name, model_name="CNN"):
#     from tensorflow.keras.models import Model
#     import matplotlib.pyplot as plt
#     import numpy as np
# 
    # Aseguramos batch
#     if img.ndim == 3:
#         img = img.reshape(1, *img.shape)
# 
    # Modelo intermedio para activaciones
# Construcción o carga del modelo: arquitectura y pesos.
#     conv_model = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
# Predicción: obtener probabilidades o etiquetas desde el modelo entrenado.
#     activations = conv_model.predict(img)  # shape: (1,H,W,C)
# 
    # Promedio absoluto de activaciones por filtro
#     avg_activations = np.mean(np.abs(activations), axis=(1,2))  # shape: (1,C)
#     avg_activations = avg_activations.flatten()
# 
    # Gráfica
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.figure(figsize=(12,4))
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.bar(range(1, len(avg_activations)+1), avg_activations, color='skyblue')
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.xlabel("Filtro")
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.ylabel("Magnitud promedio de activación")
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.title(f"Resumen de activaciones - {model_name} ({layer_name})")
# Visualización: generar gráficos o imágenes para interpretar resultados.
#     plt.show()
# 
# plot_activation_summary(cnn_profundo, base_img, layer_name="conv2d_1", model_name="CNN Profunda")
# plot_activation_summary(cnn_profundo, base_img, layer_name="conv2d_2", model_name="CNN Profunda")
# plot_activation_summary(cnn_profundo, base_img, layer_name="conv2d_3", model_name="CNN Profunda")
# plot_activation_summary(cnn_profundo, base_img, layer_name="conv2d_4", model_name="CNN Profunda")
#
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# import numpy as np
# import matplotlib.pyplot as plt
# from IPython.display import display
# Cargar y preprocesar los datos (ej. MNIST).
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.utils import to_categorical
# 
# ============================================
# Cargar y preprocesar los datos (ej. MNIST).
# 1️⃣ Cargar y preparar MNIST
# ============================================
# Cargar y preprocesar los datos (ej. MNIST).
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
# 
# Normalización y expansión de canal
# x_test = x_test.astype("float32") / 255.0
# x_test = np.expand_dims(x_test, -1)  # (28,28,1)
# y_test_cat = to_categorical(y_test, 10)
# 
# ============================================
# 2️⃣ Cargar tu modelo CNN Profundo
# ============================================
# (Si ya lo definiste en tu notebook, solo asegúrate de que cnn_profundo esté entrenado)
# cnn_profundo.load_weights('pesos_cnn_profundo.h5')  # si ya tienes pesos guardados
# 
# ============================================
# 3️⃣ Seleccionar y mostrar una imagen de prueba
# ============================================
# idx = 0  # puedes cambiar el índice
# img = x_test[idx]
# label = y_test[idx]
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.imshow(img.squeeze(), cmap='gray')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.title(f'Imagen de prueba — Etiqueta real: {label}')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.axis('off')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.show()
# 
# ============================================
# 4️⃣ Realizar la predicción con tu modelo
# ============================================
# img_array = np.expand_dims(img, axis=0)
# Predicción: obtener probabilidades o etiquetas desde el modelo entrenado.
# preds = cnn_profundo.predict(img_array)
# predicted_class = np.argmax(preds[0])
# 
# print(f"✅ Clase real: {label} — Clase predicha: {predicted_class}")
# print("Predicciones:", preds)
#
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# ✅ Clase real: 7 — Clase predicha: 7
# Predicciones: [[2.0596959e-20 1.1304839e-16 1.3497963e-22 4.7672329e-18 1.2416969e-25
#   2.2803343e-22 2.2668717e-31 1.0000000e+00 2.6435014e-20 3.1753987e-16]]

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# Definición de función: get_img_array — explica qué hace y sus parámetros.
# def get_img_array(img_path, size=(299, 299)):
    # `img` is a PIL image of size 299x299
#     img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
#     array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
#     array = np.expand_dims(array, axis=0)
#     return array
# 
# 
# Definición de función: get_gradients — explica qué hace y sus parámetros.
# def get_gradients(img_input, top_pred_idx):
#     """Computes the gradients of outputs w.r.t input image.
# 
#     Args:
#         img_input: 4D image tensor
#         top_pred_idx: Predicted label for the input image
# 
#     Returns:
#         Gradients of the predictions w.r.t img_input
#     """
#     images = tf.cast(img_input, tf.float32)
# 
#     with tf.GradientTape() as tape:
#         tape.watch(images)
#         preds = model(images)
#         top_class = preds[:, top_pred_idx]
# 
#     grads = tape.gradient(top_class, images)
#     return grads
# 
# 
# Definición de función: get_integrated_gradients — explica qué hace y sus parámetros.
# def get_integrated_gradients(img_input, top_pred_idx, baseline=None, num_steps=50):
#     """Computes Integrated Gradients for a predicted label.
# 
#     Args:
#         img_input (ndarray): Original image
#         top_pred_idx: Predicted label for the input image
#         baseline (ndarray): The baseline image to start with for interpolation
#         num_steps: Number of interpolation steps between the baseline
#             and the input used in the computation of integrated gradients. These
#             steps along determine the integral approximation error. By default,
#             num_steps is set to 50.
# 
#     Returns:
#         Integrated gradients w.r.t input image
#     """
    # If baseline is not provided, start with a black image
    # having same size as the input image.
#     if baseline is None:
#         baseline = np.zeros(img_size).astype(np.float32)
#     else:
#         baseline = baseline.astype(np.float32)
# 
    # 1. Do interpolation.
#     img_input = img_input.astype(np.float32)
#     interpolated_image = [
#         baseline + (step / num_steps) * (img_input - baseline)
#         for step in range(num_steps + 1)
#     ]
#     interpolated_image = np.array(interpolated_image).astype(np.float32)
# 
    # 2. Preprocess the interpolated images
#     interpolated_image = xception.preprocess_input(interpolated_image)
# 
    # 3. Get the gradients
#     grads = []
#     for i, img in enumerate(interpolated_image):
#         img = tf.expand_dims(img, axis=0)
#         grad = get_gradients(img, top_pred_idx=top_pred_idx)
#         grads.append(grad[0])
#     grads = tf.convert_to_tensor(grads, dtype=tf.float32)
# 
    # 4. Approximate the integral using the trapezoidal rule
#     grads = (grads[:-1] + grads[1:]) / 2.0
#     avg_grads = tf.reduce_mean(grads, axis=0)
# 
    # 5. Calculate integrated gradients and return
#     integrated_grads = (img_input - baseline) * avg_grads
#     return integrated_grads
# 
# 
# Definición de función: random_baseline_integrated_gradients — explica qué hace y sus parámetros.
# def random_baseline_integrated_gradients(
#     img_input, top_pred_idx, num_steps=50, num_runs=2
# ):
#     """Generates a number of random baseline images.
# 
#     Args:
#         img_input (ndarray): 3D image
#         top_pred_idx: Predicted label for the input image
#         num_steps: Number of interpolation steps between the baseline
#             and the input used in the computation of integrated gradients. These
#             steps along determine the integral approximation error. By default,
#             num_steps is set to 50.
#         num_runs: number of baseline images to generate
# 
#     Returns:
#         Averaged integrated gradients for `num_runs` baseline images
#     """
    # 1. List to keep track of Integrated Gradients (IG) for all the images
#     integrated_grads = []
# 
    # 2. Get the integrated gradients for all the baselines
#     for run in range(num_runs):
#         baseline = np.random.random(img_size) * 255
#         igrads = get_integrated_gradients(
#             img_input=img_input,
#             top_pred_idx=top_pred_idx,
#             baseline=baseline,
#             num_steps=num_steps,
#         )
#         integrated_grads.append(igrads)
# 
    # 3. Return the average integrated gradients for the image
#     integrated_grads = tf.convert_to_tensor(integrated_grads)
#     return tf.reduce_mean(integrated_grads, axis=0)

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# class GradVisualizer:
#     """Plot gradients of the outputs w.r.t an input image."""
# 
# Definición de función: __init__ — explica qué hace y sus parámetros.
#     def __init__(self, positive_channel=None, negative_channel=None):
#         if positive_channel is None:
#             self.positive_channel = [0, 255, 0]
#         else:
#             self.positive_channel = positive_channel
# 
#         if negative_channel is None:
#             self.negative_channel = [255, 0, 0]
#         else:
#             self.negative_channel = negative_channel
# 
# Definición de función: apply_polarity — explica qué hace y sus parámetros.
#     def apply_polarity(self, attributions, polarity):
#         if polarity == "positive":
#             return np.clip(attributions, 0, 1)
#         else:
#             return np.clip(attributions, -1, 0)
# 
# Definición de función: apply_linear_transformation — explica qué hace y sus parámetros.
#     def apply_linear_transformation(
#         self,
#         attributions,
#         clip_above_percentile=99.9,
#         clip_below_percentile=70.0,
#         lower_end=0.2,
#     ):
        # 1. Get the thresholds
#         m = self.get_thresholded_attributions(
#             attributions, percentage=100 - clip_above_percentile
#         )
#         e = self.get_thresholded_attributions(
#             attributions, percentage=100 - clip_below_percentile
#         )
# 
        # 2. Transform the attributions by a linear function f(x) = a*x + b such that
        # f(m) = 1.0 and f(e) = lower_end
#         transformed_attributions = (1 - lower_end) * (np.abs(attributions) - e) / (
#             m - e
#         ) + lower_end
# 
        # 3. Make sure that the sign of transformed attributions is the same as original attributions
#         transformed_attributions *= np.sign(attributions)
# 
        # 4. Only keep values that are bigger than the lower_end
#         transformed_attributions *= transformed_attributions >= lower_end
# 
        # 5. Clip values and return
#         transformed_attributions = np.clip(transformed_attributions, 0.0, 1.0)
#         return transformed_attributions
# 
# Definición de función: get_thresholded_attributions — explica qué hace y sus parámetros.
#     def get_thresholded_attributions(self, attributions, percentage):
#         if percentage == 100.0:
#             return np.min(attributions)
# 
        # 1. Flatten the attributions
#         flatten_attr = attributions.flatten()
# 
        # 2. Get the sum of the attributions
#         total = np.sum(flatten_attr)
# 
        # 3. Sort the attributions from largest to smallest.
#         sorted_attributions = np.sort(np.abs(flatten_attr))[::-1]
# 
        # 4. Calculate the percentage of the total sum that each attribution
        # and the values about it contribute.
#         cum_sum = 100.0 * np.cumsum(sorted_attributions) / total
# 
        # 5. Threshold the attributions by the percentage
#         indices_to_consider = np.where(cum_sum >= percentage)[0][0]
# 
        # 6. Select the desired attributions and return
#         attributions = sorted_attributions[indices_to_consider]
#         return attributions
# 
# Definición de función: binarize — explica qué hace y sus parámetros.
#     def binarize(self, attributions, threshold=0.001):
#         return attributions > threshold
# 
# Definición de función: morphological_cleanup_fn — explica qué hace y sus parámetros.
#     def morphological_cleanup_fn(self, attributions, structure=np.ones((4, 4))):
#         closed = ndimage.grey_closing(attributions, structure=structure)
#         opened = ndimage.grey_opening(closed, structure=structure)
#         return opened
# 
# Definición de función: draw_outlines — explica qué hace y sus parámetros.
#     def draw_outlines(
#         self,
#         attributions,
#         percentage=90,
#         connected_component_structure=np.ones((3, 3)),
#     ):
        # 1. Binarize the attributions.
#         attributions = self.binarize(attributions)
# 
        # 2. Fill the gaps
#         attributions = ndimage.binary_fill_holes(attributions)
# 
        # 3. Compute connected components
#         connected_components, num_comp = ndimage.label(
#             attributions, structure=connected_component_structure
#         )
# 
        # 4. Sum up the attributions for each component
#         total = np.sum(attributions[connected_components > 0])
#         component_sums = []
#         for comp in range(1, num_comp + 1):
#             mask = connected_components == comp
#             component_sum = np.sum(attributions[mask])
#             component_sums.append((component_sum, mask))
# 
        # 5. Compute the percentage of top components to keep
#         sorted_sums_and_masks = sorted(component_sums, key=lambda x: x[0], reverse=True)
#         sorted_sums = list(zip(*sorted_sums_and_masks))[0]
#         cumulative_sorted_sums = np.cumsum(sorted_sums)
#         cutoff_threshold = percentage * total / 100
#         cutoff_idx = np.where(cumulative_sorted_sums >= cutoff_threshold)[0][0]
#         if cutoff_idx > 2:
#             cutoff_idx = 2
# 
        # 6. Set the values for the kept components
#         border_mask = np.zeros_like(attributions)
#         for i in range(cutoff_idx + 1):
#             border_mask[sorted_sums_and_masks[i][1]] = 1
# 
        # 7. Make the mask hollow and show only the border
#         eroded_mask = ndimage.binary_erosion(border_mask, iterations=1)
#         border_mask[eroded_mask] = 0
# 
        # 8. Return the outlined mask
#         return border_mask
# 
# Definición de función: process_grads — explica qué hace y sus parámetros.
#     def process_grads(
#         self,
#         image,
#         attributions,
#         polarity="positive",
#         clip_above_percentile=99.9,
#         clip_below_percentile=0,
#         morphological_cleanup=False,
#         structure=np.ones((3, 3)),
#         outlines=False,
#         outlines_component_percentage=90,
#         overlay=True,
#     ):
#         if polarity not in ["positive", "negative"]:
#             raise ValueError(
#                 f""" Allowed polarity values: 'positive' or 'negative'
#                                     but provided {polarity}"""
#             )
#         if clip_above_percentile < 0 or clip_above_percentile > 100:
#             raise ValueError("clip_above_percentile must be in [0, 100]")
# 
#         if clip_below_percentile < 0 or clip_below_percentile > 100:
#             raise ValueError("clip_below_percentile must be in [0, 100]")
# 
        # 1. Apply polarity
#         if polarity == "positive":
#             attributions = self.apply_polarity(attributions, polarity=polarity)
#             channel = self.positive_channel
#         else:
#             attributions = self.apply_polarity(attributions, polarity=polarity)
#             attributions = np.abs(attributions)
#             channel = self.negative_channel
# 
        # 2. Take average over the channels
#         attributions = np.average(attributions, axis=2)
# 
        # 3. Apply linear transformation to the attributions
#         attributions = self.apply_linear_transformation(
#             attributions,
#             clip_above_percentile=clip_above_percentile,
#             clip_below_percentile=clip_below_percentile,
#             lower_end=0.0,
#         )
# 
        # 4. Cleanup
#         if morphological_cleanup:
#             attributions = self.morphological_cleanup_fn(
#                 attributions, structure=structure
#             )
        # 5. Draw the outlines
#         if outlines:
#             attributions = self.draw_outlines(
#                 attributions, percentage=outlines_component_percentage
#             )
# 
        # 6. Expand the channel axis and convert to RGB
#         attributions = np.expand_dims(attributions, 2) * channel
# 
        # 7.Superimpose on the original image
#         if overlay:
#             attributions = np.clip((attributions * 0.8 + image), 0, 255)
#         return attributions
# 
# Definición de función: visualize — explica qué hace y sus parámetros.
#     def visualize(
#         self,
#         image,
#         gradients,
#         integrated_gradients,
#         polarity="positive",
#         clip_above_percentile=99.9,
#         clip_below_percentile=0,
#         morphological_cleanup=False,
#         structure=np.ones((3, 3)),
#         outlines=False,
#         outlines_component_percentage=90,
#         overlay=True,
#         figsize=(15, 8),
#     ):
        # 1. Make two copies of the original image
#         img1 = np.copy(image)
#         img2 = np.copy(image)
# 
        # 2. Process the normal gradients
#         grads_attr = self.process_grads(
#             image=img1,
#             attributions=gradients,
#             polarity=polarity,
#             clip_above_percentile=clip_above_percentile,
#             clip_below_percentile=clip_below_percentile,
#             morphological_cleanup=morphological_cleanup,
#             structure=structure,
#             outlines=outlines,
#             outlines_component_percentage=outlines_component_percentage,
#             overlay=overlay,
#         )
# 
        # 3. Process the integrated gradients
#         igrads_attr = self.process_grads(
#             image=img2,
#             attributions=integrated_gradients,
#             polarity=polarity,
#             clip_above_percentile=clip_above_percentile,
#             clip_below_percentile=clip_below_percentile,
#             morphological_cleanup=morphological_cleanup,
#             structure=structure,
#             outlines=outlines,
#             outlines_component_percentage=outlines_component_percentage,
#             overlay=overlay,
#         )
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         _, ax = plt.subplots(1, 3, figsize=figsize)
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         ax[0].imshow(image)
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         ax[1].imshow(grads_attr.astype(np.uint8))
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         ax[2].imshow(igrads_attr.astype(np.uint8))
# 
#         ax[0].set_title("Input")
#         ax[1].set_title("Normal gradients")
#         ax[2].set_title("Integrated gradients")
# Visualización: generar gráficos o imágenes para interpretar resultados.
#         plt.show()

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt
# 
# ============================================
# Cargar y preprocesar los datos (ej. MNIST).
# 1️⃣ Convertir la imagen (ya cargada de MNIST) a arreglo compatible
# ============================================
# img_array = np.expand_dims(img, axis=0)  # (1, 28, 28, 1)
# orig_img = np.copy(img.squeeze())  # copia para mostrar
# 
# ============================================
# 2️⃣ Obtener predicciones del modelo
# ============================================
# Predicción: obtener probabilidades o etiquetas desde el modelo entrenado.
# preds = cnn_profundo.predict(img_array)
# top_pred_idx = tf.argmax(preds[0])
# 
# print(f"✅ Clase real: {label} — Clase predicha: {top_pred_idx.numpy()}")
# print("Predicciones:", preds)
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# 
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# ============================================
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# 3️⃣ Calcular gradientes (Grad-CAM base)
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# ============================================
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# Escogemos la última capa convolucional
# last_conv_layer = cnn_profundo.get_layer("conv2d_2")
# 
# Usamos GradientTape para obtener gradientes
# with tf.GradientTape() as tape:
#     inputs = tf.cast(img_array, tf.float32)
#     tape.watch(inputs)
# Construcción o carga del modelo: arquitectura y pesos.
#     last_conv_output, preds_output = tf.keras.models.Model(
#         [cnn_profundo.inputs],
#         [last_conv_layer.output, cnn_profundo.output]
#     )(inputs)
#     loss = preds_output[:, top_pred_idx]
# 
# Gradientes respecto a la última capa
# grads = tape.gradient(loss, last_conv_output)
# 
# ============================================
# 4️⃣ Generar el mapa de activación
# ============================================
# pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
# heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_output), axis=-1)[0]
# 
# Normalización
# heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# 
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# ============================================
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# 5️⃣ Visualizar Grad-CAM
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# ============================================
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.figure(figsize=(6, 3))
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.subplot(1, 2, 1)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.imshow(orig_img, cmap='gray')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.title("Imagen original")
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.axis("off")
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.subplot(1, 2, 2)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.imshow(orig_img, cmap='gray')
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.imshow(heatmap, cmap='jet', alpha=0.5)
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.title("Mapa de activación (Grad-CAM)")
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.axis("off")
# Generación de mapás de activación con Grad-CAM: explica la lógica principal.
# 
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.tight_layout()
# Visualización: generar gráficos o imágenes para interpretar resultados.
# plt.show()
#
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# ✅ Clase real: 7 — Clase predicha: 7
# Predicciones: [[2.0596959e-20 1.1304839e-16 1.3497963e-22 4.7672329e-18 1.2416969e-25
#   2.2803343e-22 2.2668717e-31 1.0000000e+00 2.6435014e-20 3.1753987e-16]]

# %%
# Explicación: Esta celda realiza una tarea específica del flujo del notebook. Lee el comentario para entender su propósito y luego ejecuta el código.
#Referencias
#https://keras-io.translate.goog/examples/vision/integrated_gradients/?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=tc

# %% [markdown]
# ## 📚 Referencias
# - Chollet, F. (2017). *Xception: Deep Learning with Depthwise Separable Convolutions.* Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR).
# - Keras Documentation — [https://keras.io/](https://keras.io/)
# - TensorFlow Documentation — [https://www.tensorflow.org/api_docs](https://www.tensorflow.org/api_docs)
# - Selvaraju, R. R. et al. (2017). *Grad-CAM: Visual Explanations from Deep Networks via Gradient-based Localization.* Proceedings of the IEEE International Conference on Computer Vision (ICCV).
# - Dataset MNIST — [http://yann.lecun.com/exdb/mnist/](http://yann.lecun.com/exdb/mnist/)
